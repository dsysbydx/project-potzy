# %%
# %run 'header.ipynb'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#load ticker
ticker = 'CPALL'
df = pd.read_csv('../data/th/fs/'+ticker+'.csv',parse_dates=[0],index_col=[0]).sort_index(ascending=False)

#bug in new data from 
df = df[df.index.date < dt.date(2017,4,1)].sort_index()

# %%
df.tail()
# Out:
#               revenue  net_profit       eps       dps  gross_profit     ebit  \
# 2016-03-31  108785.53     4064.68  0.450000  0.000000      22716.04  7113.13
# 2016-06-30  114628.65     4195.95  0.467310  0.900000      23962.30  7142.46
# 2016-09-30  113027.62     4115.17  0.458874 -0.001101      24042.45  7144.98
# 2016-12-31  115497.05     4300.71  0.477097  0.004629      24303.03  7184.18
# 2017-03-31  117512.53     4764.99  0.520000  0.000000      24894.44  7799.57
#
#               ebitda
# 2016-03-31   9053.10
# 2016-06-30   9184.09
# 2016-09-30   9291.03
# 2016-12-31   9370.54
# 2017-03-31  10086.34

# %%
df.columns
# Out:
# Index(['revenue', 'net_profit', 'eps', 'dps', 'gross_profit', 'ebit',
#        'ebitda'],
#       dtype='object')

# %%
df['eps'].rolling(window=1).sum().plot(kind='bar')
plt.figure()
df['la
   '].plot(kind='bar')
