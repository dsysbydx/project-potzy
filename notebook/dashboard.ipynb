# %%
# %run 'header.ipynb'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#load ticker
ticker = 'CPALL'
df = pd.read_csv('../data/th/fs/'+ticker+'.csv',parse_dates=[0],index_col=[0]).sort_index(ascending=False)

#bug in new data from 
df = df[df.index.date < dt.date(2017,4,1)].sort_index()

# %%
df['net_profit'].plot(kind='bar')
plt.figure()
df['revenue'].plot(kind='bar')

# %%
import potzy.da as db

db = financialDataApi()

#initializ

#load data

#
